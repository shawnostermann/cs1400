# %%
# CS1400 Scratchpad for Midterm 2 - October 2021

# This cell will install all of the pieces you need for 
# Turtle programming
#
from calysto.graphics import *
from calysto.display import display, clear_output
import time
import math

# Here's a function that you can use to "show" what you're drawing from time to time.
# Note that, until you call these routines, the drawing won't appear
# The argument is the canvas to use
def SHOW(c):
    """" Show the canvas passed as an argument
    """
    clear_output(wait=True)  # if you don't clear, than every call to SHOW makes more output
    display(c)

# %% [markdown]
# ## Midterm2 Turtle Question #1
#
# Complete the function
#
# `def triangle(t,length):`
#
# that uses the turtle "t" to draw an equilateral
# (all sides are the same length) triangle where
# each side has length "length".
# - The pointed part of the triangle should be facing UP
# and the "bottom" should be the horizontal side
# - The initial turtle position should be the lower left corner
# of the triangle
# - At the end of the function, the turtle should be in
# the same location and facing the same direction as it
# was at the beginning of the function.
#
# It should look like this:
#
# ![image.png](attachment:e220ba8a-d532-405f-a408-3acd1c5ba49c.png)

# %%
# Use this canvas to make the drawing
canvas = Canvas(size=(400, 400))

# Use turtle, donnie, to do the drawing 
# This turtle starts facing to the right
donnie = Turtle(canvas, (200, 300), 0)

#
# write your answer here
# 
def triangle(t, length):
    print("Put your python code here")

    
# test your first triangle answer
triangle(donnie,200)
SHOW(canvas)

# when you have it working, paste all of the function
# "triangle" onto the blackboard midterm question

# %% [markdown]
# ## Midterm2 Turtle Question #2
#
# Complete the function
#
# `def drawtrianglehere(t,length,x,y):`
#
# that calls the triangle function that your wrote
# in question one, but starts drawing the triangle at
# position (x,y) (by moving the turtle to that
# (x,y) position WITHOUT drawing a line to get there)
#
# It should look like this (when the driver code at the bottom calls it 3 times):
#
# ![image.png](attachment:33e7d5ea-1c48-4be5-9276-feeb8b078a52.png)

# %%
# Use this canvas to make the drawing
canvas = Canvas(size=(400, 400))

# Use turtle, donnie, to do the drawing 
# This turtle starts facing to the right
donnie = Turtle(canvas, (200, 300), 0)

#
# write your answer here
# 
def drawtrianglehere(t, length, x, y):
    print("Put your python code here")

    
# test your second triangle function answer
# draws 3 triangles in a line with their corners touching
drawtrianglehere(donnie,200,50,350)
drawtrianglehere(donnie,100,250,350)
drawtrianglehere(donnie,50 ,350,350)
SHOW(canvas)

# when you have it working, paste all of the function
# "drawtrianglehere" onto the blackboard midterm question

# %% [markdown]
# ## Midterm2 Turtle Question #3
#
# Complete the function
#
# `def recurse(t,length,x,y):`
#
# that uses the `drawtrianglehere()` function that your wrote
# in question two.
# - Use recursion to draw nested triangles whose lower left
# hand corners are all at location (x,y)
# - Each successive, recursive triangle should have sides
# whose length are 95% of the previous one
# - If the length of the side is less than 2, the function
# should return without drawing anything
#
# It should look like this (when the driver code at the bottom calls it):
#
# ![image.png](attachment:65e99eb7-50f8-4a47-8f09-3c679fe1ec69.png)

# %%
# Use this canvas to make the drawing
canvas = Canvas(size=(400, 400))

# Use turtle, donnie, to do the drawing 
# This turtle starts facing to the right
donnie = Turtle(canvas, (200, 300), 0)

#
# write your answer here
# 
def recurse(t, length, x, y):
    print("Put your python code here")

    
# test your recursive  triangle function answer
# this should draw 3 triangles in a row
recurse(donnie,300,50,350)
SHOW(canvas)

# when you have it working, paste all of the function
# "recurse" onto the blackboard midterm question
