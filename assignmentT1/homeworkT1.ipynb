# %%
# CS1400 HW - T1 - Turtle Calculator
# Include the modules that you'll need for the project
#
from calysto.graphics import *
from calysto.display import display, clear_output
import time
import math

# %%
# This creates the "canvas" that we'll be drawing on
canvas = Canvas(size=(400, 400))

# Here's an example turtle that you might use for drawing
donnie = Turtle(canvas, (200, 200), 0)

# %%
# Here's a function that you can use to "show" what you're drawing from time to time.
# Note that, until you call these routines, the drawing won't appear
# The argument is the canvas to use
def SHOW(c):
    """" Show the canvas passed as an argument
    """
    #clear_output(wait=True)  # if you don't clear, than every call to SHOW makes more output
    display(c)

# %%
# As a reminder, here are all of the functions that you can use for drawing
#

# first, clear the canvas and start over with a new turtle
canvas = Canvas(size=(400, 400))
donnie = Turtle(canvas, (200, 200), 0)

# Simple commands to just move around a little
donnie.forward(100)
donnie.left(45)
donnie.forward(100)
donnie.right(45)
donnie.backward(50)
# move without drawing
donnie.penup()
donnie.goto(100,100)
donnie.pendown()
donnie.forward(100)
# change the color (in RGB)
donnie.stroke = Color(255, 0, 0)
donnie.forward(100)
donnie.stroke = Color(0, 255, 0)
donnie.forward(100)
donnie.forward(100)
# Now, show what's been drawn
SHOW(canvas)

# %% [markdown]
# ## Homework Part 1 (5 points)
# <br>
# Write functions draw_0, draw_1, and draw_9 that take one parameter (t) that draw the numbers 0, 1, and 9 (respectively) of sized 100 (height) by 50 (width) at the current location of the turtle t.

# %%
def draw_0(t):
    t.left(90)
    t.forward(100)
    todo = "Finish this function"

    
def draw_1(t):
    todo = "Finish this function"


def draw_9(t):
    todo = "Finish this function"

# %%
#
# test the first 3 digits for the homework by running this code
#
canvas_width=500
canvas_height=300
canvas = Canvas(size=(canvas_width, canvas_height))
t1 = Turtle(canvas, (100,100), 0)
# go to the lower left corner, facing up
t1.penup()
t1.goto(0,canvas_height)
t1.angle = 0
t1.left(90)
t1.pendown()

# draw a border in red
t1.stroke = Color(255,0,0)
t1.stroke_width = 10
t1.forward(canvas_height)
t1.right(90)
t1.forward(canvas_width)
t1.right(90)
t1.forward(canvas_height)
t1.right(90)
t1.forward(canvas_width)
t1.stroke = Color(0,0,0)  # change back to black
t1.stroke_width = 1
t1.stroke_width = 5
SHOW(canvas)

#
# draw a 0 in black
t1.stroke = Color(0, 0, 0)
t1.stroke_width = 5
t1.penup()
t1.goto(100,200)
t1.pendown()
t1.angle=0 # make turtle face RIGHT
draw_0(t1) # this is your code from above

#
# draw a 1 in green
t1.stroke = Color(0, 255, 0)
t1.stroke_width = 5
t1.penup()
t1.goto(200,200)
t1.pendown()
t1.angle=0 # make turtle face RIGHT
draw_1(t1) # this is your code from above

#
# draw a 9 in blue
t1.stroke = Color(0, 0, 255)
t1.stroke_width = 5
t1.penup()
t1.goto(300,200)
t1.pendown()
t1.angle=0 # make turtle face RIGHT
draw_9(t1) # this is your code from above

SHOW(canvas)

# %% [markdown]
# ## Homework Part 2 (10 points)
# <br>
# Write functions draw_2, draw_3, and draw_5 that take three parameters (t, h, w) that draw the numbers 2, 3, and 5 (respectively) of height h and width w at the current location of the turtle bot t.

# %%
def draw_2(t, h, w):
    todo = "Finish this function"


def draw_3(t, h, w):
    todo = "Finish this function"

    
def draw_5(t, h, w):
    todo = "Finish this function"

# %%
#
# test the second 3 digits for the homework by running this code
#
canvas_width=500
canvas_height=300
canvas = Canvas(size=(canvas_width, canvas_height))
t1 = Turtle(canvas, (100,100), 0)
# go to the lower left corner, facing up
t1.penup()
t1.goto(0,canvas_height)
t1.angle = 0
t1.left(90)
t1.pendown()

# draw a border in purple
t1.stroke = Color(255,0,255)
t1.stroke_width = 10
t1.forward(canvas_height)
t1.right(90)
t1.forward(canvas_width)
t1.right(90)
t1.forward(canvas_height)
t1.right(90)
t1.forward(canvas_width)
t1.stroke = Color(0,0,0)  # change back to black
t1.stroke_width = 1
t1.stroke_width = 5
SHOW(canvas)

#
# draw a 2 in red
t1.stroke = Color(255, 0, 0)
t1.stroke_width = 5
t1.penup()
t1.goto(100,200)
t1.pendown()
t1.angle=0 # make turtle face RIGHT
draw_2(t1,70,35) # this is your code from above

#
# draw a 3 in purple
t1.stroke = Color(255, 0, 255)
t1.stroke_width = 5
t1.penup()
t1.goto(200,200)
t1.pendown()
t1.angle=0 # make turtle face RIGHT
draw_3(t1,70,35) # this is your code from above

#
# draw a 5 in blue
t1.stroke = Color(0, 0, 255)
t1.stroke_width = 5
t1.penup()
t1.goto(300,200)
t1.pendown()
t1.angle=0 # make turtle face RIGHT
draw_5(t1,70,35) # this is your code from above

SHOW(canvas)

# %% [markdown]
# ## Homework Part 3 (10 points)
# <br>
# Write functions draw_4, draw_6, draw_7, and draw_8 that take five parameters (t,h,w,x,y) that move to location x,y on the turtle-bot world and draw the numbers 4, 6, 7, and 8, respectively, of height h and width w.

# %%
def draw_4(t, h, w, x, y):
    todo = "Finish this function"
    
    
def draw_6(t, h, w, x, y):
    todo = "Finish this function"
   

def draw_7(t, h, w, x, y):
    todo = "Finish this function"

    
def draw_8(t, h, w, x, y):
    todo = "Finish this function"

# %%
#
# test the final 4 digits for the homework by running this code
#
canvas_width=500
canvas_height=300
canvas = Canvas(size=(canvas_width, canvas_height))
t1 = Turtle(canvas, (100,100), 0)
# go to the lower left corner, facing up
t1.penup()
t1.goto(0,canvas_height)
t1.angle = 0
t1.left(90)
t1.pendown()

# draw a border in orange
t1.stroke = Color(255,172,0)
t1.stroke_width = 10
t1.forward(canvas_height)
t1.right(90)
t1.forward(canvas_width)
t1.right(90)
t1.forward(canvas_height)
t1.right(90)
t1.forward(canvas_width)
t1.stroke = Color(0,0,0)  # change back to black
t1.stroke_width = 1
t1.stroke_width = 5
SHOW(canvas)

#
# draw a 4 in red
t1.stroke = Color(255, 0, 0)
t1.angle=0 # make turtle face RIGHT
draw_4(t1,120,60,50,200) # this is your code from above

#
# draw a 6 in lime
t1.stroke = Color(0, 255, 0)
t1.angle=0 # make turtle face RIGHT
draw_6(t1,120,60,150,200) # this is your code from above

#
# draw a 7 in cyan
t1.stroke = Color(255, 0, 0)
t1.angle=0 # make turtle face RIGHT
draw_7(t1,120,60,250,200) # this is your code from above

#
# draw a 8 in light purple
t1.stroke = Color(255, 102, 255)
t1.angle=0 # make turtle face RIGHT
draw_8(t1,120,60,350,200) # this is your code from above


SHOW(canvas)

# %% [markdown]
# ## (10 pts. EXTRA CREDIT) <br>
# Write a function draw_number that takes a six parameters (t,h,w,x,y,digit) and prints the number digit using the calculator font, where each character has height h and width w, starting at location x,y. Then write a function draw_digit_chart(t) that uses that to draw the image below, separating the digits with space equal to w/10.

# %%
def draw_number(t, h, w, x, y, digit):
    #print("Digit is", digit)
    #print("Position is", x, y)
    #print("Size is", h, w)
    

    # this might be a good way to start...
    #
    t.angle=0 # make turtle face RIGHT
    if (digit == 4):
        draw_4(t, h, w, x, y)
    elif
        todo = "Finish this function"



    
    
# write this one too, to draw the chart    
def draw_digit_chart(t):
    ix = 0
    width=50
    height=100
    t.stroke = Color(0, 0, 0)
    todo = "Finish this function"

# %%
# test your extra credit with this code...
canvas_width=700
canvas_height=500
canvas = Canvas(size=(canvas_width, canvas_height))
t1 = Turtle(canvas, (100,100), 0)
# go to the lower left corner, facing up
t1.penup()
t1.goto(0,canvas_height)
t1.angle = 0
t1.left(90)
t1.pendown()

# draw a border in navy blue
t1.stroke = Color(0,76,153)
t1.stroke_width = 10
t1.forward(canvas_height)
t1.right(90)
t1.forward(canvas_width)
t1.right(90)
t1.forward(canvas_height)
t1.right(90)
t1.forward(canvas_width)
t1.stroke = Color(0,0,0)  # change back to black
t1.stroke_width = 1
t1.stroke_width = 5
SHOW(canvas)

draw_digit_chart(t1)  # this is your extra credit function
SHOW(canvas)
